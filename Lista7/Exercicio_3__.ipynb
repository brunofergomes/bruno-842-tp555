# %%
# Import all necessary libraries.
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.datasets import make_moons
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, auc, classification_report
import seaborn as sns
from IPython.display import Image  
#from sklearn.externals.six import StringIO  
from sklearn.model_selection import GridSearchCV

# %%
# Create Database
x, y = make_moons(n_samples = 10000, noise = 0.4, random_state=42)

# %%
# Split array into random train and test subsets.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
idx0 = np.argwhere(y == 0)
idx1 = np.argwhere(y == 1)

fig = plt.figure(figsize=(6,6))
plt.plot(x[idx0,0], x[idx0,1], 'o', label='Class 0')
plt.plot(x[idx1,0], x[idx1,1], 'gx', label='Class 1')
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$x_2$', fontsize=14)
plt.legend()
#plt.savefig('knn_for_two_classes.png', dpi=600)
plt.show()

# %%
# Set parameters for grid-search.
param_grid = [{'criterion': ['gini', 'entropy'], 'max_depth': [None, 1, 2, 5, 10, 15, 25], 'max_leaf_nodes': [None, 2, 5, 10, 15, 25, 50, 100]}]

# Instantiate DT class.
dtc = DecisionTreeClassifier()
grid_search = GridSearchCV(dtc, param_grid, cv=5, verbose=3, n_jobs=-1)

# Find best hyperparameters.
grid_search.fit(x, y)


print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 112 candidates, totalling 560 fits
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=None .............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=None, score=0.805, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=None .............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=None, score=0.798, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=None .............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=None, score=0.791, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=None .............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=None, score=0.808, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=None .............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=None, score=0.795, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=2 ................
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=2, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=2 ................
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=2, score=0.757, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=2 ................
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=2, score=0.771, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=2 ................
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=2, score=0.783, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=2 ................
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=2, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=5 ................
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=5, score=0.864, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=5 ................
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=5, score=0.851, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=5 ................
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=5, score=0.841, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=5 ................
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=5, score=0.866, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=5 ................
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=5, score=0.863, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=10 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=10, score=0.864, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=10 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=10, score=0.851, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=10 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=10, score=0.841, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=10 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=10, score=0.859, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=10 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=10, score=0.863, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=15 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=15, score=0.862, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=15 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=15, score=0.851, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=15 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=15, score=0.849, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=15 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=15, score=0.859, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=15 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=15, score=0.859, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=25 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=25, score=0.869, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=25 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=25, score=0.857, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=25 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=25, score=0.846, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=25 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=25, score=0.865, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=25 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=25, score=0.862, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=50 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=50, score=0.858, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=50 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=50, score=0.854, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=50 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=50, score=0.842, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=50 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=50, score=0.868, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=50 ...............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=50, score=0.859, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=100 ..............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=100, score=0.856, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=100 ..............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=100, score=0.853, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=100 ..............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=100, score=0.845, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=100 ..............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=100, score=0.860, total=   0.0s
# [CV] criterion=gini, max_depth=None, max_leaf_nodes=100 ..............
# [CV]  criterion=gini, max_depth=None, max_leaf_nodes=100, score=0.850, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=None ................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=None, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=None ................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=None, score=0.757, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=None ................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=None, score=0.771, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=None ................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=None, score=0.783, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=None ................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=None, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=2 ...................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=2, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=2 ...................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=2, score=0.757, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=2 ...................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=2, score=0.771, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=2 ...................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=2, score=0.783, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=2 ...................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=2, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=5 ...................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=5, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=5 ...................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=5, score=0.757, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=5 ...................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=5, score=0.771, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=5 ...................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=5, score=0.783, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=5 ...................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=5, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=10 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=10, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=10 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=10, score=0.757, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=10 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=10, score=0.771, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=10 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=10, score=0.783, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=10 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=10, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=15 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=15, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=15 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=15, score=0.757, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=15 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=15, score=0.771, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=15 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=15, score=0.783, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=15 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=15, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=25 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=25, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=25 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=25, score=0.757, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=25 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=25, score=0.771, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=25 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=25, score=0.783, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=25 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=25, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=50 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=50, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=50 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=50, score=0.757, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=50 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=50, score=0.771, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=50 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=50, score=0.783, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=50 ..................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=50, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=100 .................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=100, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=100 .................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=100, score=0.757, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=100 .................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=100, score=0.771, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=100 .................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=100, score=0.783, total=   0.0s
# [CV] criterion=gini, max_depth=1, max_leaf_nodes=100 .................
# [CV]  criterion=gini, max_depth=1, max_leaf_nodes=100, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=None ................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=None, score=0.864, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=None ................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=None, score=0.851, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=None ................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=None, score=0.841, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=None ................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=None, score=0.866, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=None ................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=None, score=0.863, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=2 ...................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=2, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=2 ...................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=2, score=0.757, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=2 ...................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=2, score=0.771, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=2 ...................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=2, score=0.783, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=2 ...................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=2, score=0.778, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=5 ...................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=5, score=0.864, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=5 ...................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=5, score=0.851, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=5 ...................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=5, score=0.841, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=5 ...................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=5, score=0.866, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=5 ...................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=5, score=0.863, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=10 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=10, score=0.864, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=10 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=10, score=0.851, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=10 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=10, score=0.841, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=10 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=10, score=0.866, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=10 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=10, score=0.863, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=15 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=15, score=0.864, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=15 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=15, score=0.851, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=15 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=15, score=0.841, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=15 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=15, score=0.866, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=15 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=15, score=0.863, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=25 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=25, score=0.864, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=25 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes=25, score=0.851, total=   0.0s
# [CV] criterion=gini, max_depth=2, max_leaf_nodes=25 ..................
# [CV]  criterion=gini, max_depth=2, max_leaf_nodes
total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=5 ...............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=5, score=0.864, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=5 ...............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=5, score=0.851, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=5 ...............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=5, score=0.841, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=5 ...............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=5, score=0.866, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=5 ...............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=5, score=0.852, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=10 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=10, score=0.864, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=10 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=10, score=0.851, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=10 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=10, score=0.841, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=10 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=10, score=0.866, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=10 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=10, score=0.852, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=15 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=15, score=0.864, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=15 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=15, score=0.851, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=15 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=15, score=0.841, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=15 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=15, score=0.866, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=15 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=15, score=0.852, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=25 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=25, score=0.865, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=25 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=25, score=0.846, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=25 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=25, score=0.850, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=25 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=25, score=0.861, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=25 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=25, score=0.863, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=50 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=50, score=0.861, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=50 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=50, score=0.855, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=50 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=50, score=0.843, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=50 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=50, score=0.860, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=50 ..............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=50, score=0.855, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=100 .............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=100, score=0.862, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=100 .............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=100, score=0.849, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=100 .............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=100, score=0.842, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=100 .............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=100, score=0.857, total=   0.0s
# [CV] criterion=entropy, max_depth=25, max_leaf_nodes=100 .............
# [CV]  criterion=entropy, max_depth=25, max_leaf_nodes=100, score=0.844, total=   0.0s
# {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 25}
# 0.8596
# [Parallel(n_jobs=-1)]: Done 560 out of 560 | elapsed:    9.6s finished

# %% [markdown]
# # Train Model for - >> Criterion= Gini & max_dep=None & max_leaf_nodes = 25

# %%
dtc = DecisionTreeClassifier(criterion='gini', max_depth = None, max_leaf_nodes = 25)

# Fit the classifier on the training features and labels.
dtc.fit(x_train, y_train)

# Use the trained classifier to predict labels for the test features.
y_pred = dtc.predict(x_test)

# Calculate and return the accuracy on the test data 
accuracy = accuracy_score(y_test, y_pred)

print('accuracy: ',accuracy)
# Out:
# accuracy:  0.8648

# %%
# visualize the decision tree.
# you've got to have graphviz and pydot installed on your computer.
# Execute: conda install graphviz pydot
dot_data = StringIO()  
tree.export_graphviz(clf, out_file=dot_data, class_names=target_names, feature_names=feature_names)
graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c03a94d132c7> in <module>
#       2 # you've got to have graphviz and pydot installed on your computer.
#       3 # Execute: conda install graphviz pydot
# ----> 4 dot_data = StringIO()
#       5 tree.export_graphviz(clf, out_file=dot_data, class_names=target_names, feature_names=feature_names)
#       6 graph = pydot.graph_from_dot_data(dot_data.getvalue())
#
# NameError: name 'StringIO' is not defined

# %%
# Plot the confusion matrix.
fig = plt.figure(figsize=(5,5))
mat = confusion_matrix(y_test, y_pred)
sns.set()
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False, xticklabels=['0','1'], yticklabels=['0','1'], cmap="Blues")
plt.xlabel('true label')
plt.ylabel('predicted label')
plt.savefig('confusion_matrix_dt.png', dpi=600)
plt.show()

# %%
# Step size in the mesh.
h = .02 

# Create color maps
cmap_light = ListedColormap(['orange', 'cyan', 'cornflowerblue'])
cmap_bold = ListedColormap(['darkorange', 'c', 'darkblue'])

plt.figure(figsize=(5, 5))
# Plot the decision boundary. For that, we will assign a color to each point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = grid_search.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot.
Z = Z.reshape(xx.shape)
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points.
plt.scatter(x[:, 0], x[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('$x_1$', fontsize=14)
plt.ylabel('$x_2$', fontsize=14)
plt.title("2-Class classification")

plt.savefig('decision_boundary_dt.png', dpi=600)
plt.show()

# %%
# Getting the probabilities for each class.
y_prob = grid_search.predict_proba(x_test)

# Compute ROC curve and ROC area for each class.
plt.figure(figsize=(5, 5))

fpr, tpr, _ = roc_curve(y_test, y_prob[:, 1])
roc_auc = auc(fpr, tpr)
# Plotting ROC curve.
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC - Class ')
plt.legend(loc="lower right")

plt.savefig('roc_dt.png', dpi=600)
plt.show()
