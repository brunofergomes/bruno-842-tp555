# %%
# Import all necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, auc, classification_report 
from sklearn.datasets import make_blobs
from sklearn.metrics import f1_score, roc_auc_score, precision_recall_curve, precision_score, recall_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model.logistic import LogisticRegression
from sklearn.preprocessing import label_binarize
import seaborn as sns

# %%
# generate 2 class dataset
x, y = make_classification(n_samples=10000, n_classes=2, weights=[0.9,0.5],
random_state=42)

# Split data into train and test subsets.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.8)

# %%
# Instantiate LogisticRegression object for multi-class case.
model = LogisticRegression(solver='lbfgs', max_iter=10000, multi_class='multinomial')

# Train model.
model.fit(x_train, y_train)

# Predict.
y_pred_log = model.predict(x_test)

# Getting the probabilities for each class.
y_prob_log = model.predict_proba(x_test)

# Binarize the test targets.
y_test_bin_log = label_binarize(y_test, classes=[0, 1, 2])

# %%
# Instantiate a Gaussian naive Bayes classifier.
gnb = GaussianNB()

# Train model.
gnb.fit(x_train, y_train)

# Predict.
y_pred_gnb = gnb.predict(x_test)

# Getting the probabilities for each class.
y_prob_gnb = gnb.predict_proba(x_test)

# Binarize the test targets.
y_test_bin_gnb = label_binarize(y_test, classes=[0, 1, 2])

# %%
parameters = [{'weights': ['uniform', 'distance'], 'n_neighbors': [1, 2, 3, 4, 5, 10, 15, 20]}]
svc = KNeighborsClassifier()

clf = GridSearchCV(svc, parameters, cv=10, verbose=3, n_jobs=-1)
clf.fit(x, y)

print(clf.best_params_)
print(clf.best_score_)
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# [CV] n_neighbors=1, weights=uniform ..................................
# [Parallel(n_jobs=-1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ...... n_neighbors=1, weights=uniform, score=0.816, total=   0.6s
# [CV] n_neighbors=1, weights=uniform ..................................
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [CV] ...... n_neighbors=1, weights=uniform, score=0.816, total=   0.6s
# [CV] n_neighbors=1, weights=uniform ..................................
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    1.2s remaining:    0.0s
# [CV] ...... n_neighbors=1, weights=uniform, score=0.824, total=   0.6s
# [CV] n_neighbors=1, weights=uniform ..................................
# [CV] ...... n_neighbors=1, weights=uniform, score=0.814, total=   0.6s
# [CV] n_neighbors=1, weights=uniform ..................................
# [CV] ...... n_neighbors=1, weights=uniform, score=0.828, total=   0.7s
# [CV] n_neighbors=1, weights=uniform ..................................
# [CV] ...... n_neighbors=1, weights=uniform, score=0.836, total=   0.7s
# [CV] n_neighbors=1, weights=uniform ..................................
# [CV] ...... n_neighbors=1, weights=uniform, score=0.811, total=   0.7s
# [CV] n_neighbors=1, weights=uniform ..................................
# [CV] ...... n_neighbors=1, weights=uniform, score=0.835, total=   0.7s
# [CV] n_neighbors=1, weights=uniform ..................................
# [CV] ...... n_neighbors=1, weights=uniform, score=0.829, total=   0.6s
# [CV] n_neighbors=1, weights=uniform ..................................
# [CV] ...... n_neighbors=1, weights=uniform, score=0.813, total=   0.7s
# [CV] n_neighbors=1, weights=distance .................................
# [CV] ..... n_neighbors=1, weights=distance, score=0.816, total=   0.7s
# [CV] n_neighbors=1, weights=distance .................................
# [CV] ..... n_neighbors=1, weights=distance, score=0.816, total=   0.7s
# [CV] n_neighbors=1, weights=distance .................................
# [CV] ..... n_neighbors=1, weights=distance, score=0.824, total=   0.6s
# [CV] n_neighbors=1, weights=distance .................................
# [CV] ..... n_neighbors=1, weights=distance, score=0.814, total=   0.6s
# [CV] n_neighbors=1, weights=distance .................................
# [CV] ..... n_neighbors=1, weights=distance, score=0.828, total=   0.7s
# [CV] n_neighbors=1, weights=distance .................................
# [CV] ..... n_neighbors=1, weights=distance, score=0.836, total=   0.6s
# [CV] n_neighbors=1, weights=distance .................................
# [CV] ..... n_neighbors=1, weights=distance, score=0.811, total=   0.6s
# [CV] n_neighbors=1, weights=distance .................................
# [CV] ..... n_neighbors=1, weights=distance, score=0.835, total=   0.6s
# [CV] n_neighbors=1, weights=distance .................................
# [CV] ..... n_neighbors=1, weights=distance, score=0.829, total=   0.6s
# [CV] n_neighbors=1, weights=distance .................................
# [CV] ..... n_neighbors=1, weights=distance, score=0.813, total=   0.5s
# [CV] n_neighbors=2, weights=uniform ..................................
# [CV] ...... n_neighbors=2, weights=uniform, score=0.830, total=   0.6s
# [CV] n_neighbors=2, weights=uniform ..................................
# [CV] ...... n_neighbors=2, weights=uniform, score=0.827, total=   0.5s
# [CV] n_neighbors=2, weights=uniform ..................................
# [CV] ...... n_neighbors=2, weights=uniform, score=0.830, total=   0.5s
# [CV] n_neighbors=2, weights=uniform ..................................
# [CV] ...... n_neighbors=2, weights=uniform, score=0.840, total=   0.6s
# [CV] n_neighbors=2, weights=uniform ..................................
# [CV] ...... n_neighbors=2, weights=uniform, score=0.836, total=   0.7s
# [CV] n_neighbors=2, weights=uniform ..................................
# [CV] ...... n_neighbors=2, weights=uniform, score=0.831, total=   0.8s
# [CV] n_neighbors=2, weights=uniform ..................................
# [CV] ...... n_neighbors=2, weights=uniform, score=0.822, total=   0.7s
# [CV] n_neighbors=2, weights=uniform ..................................
# [CV] ...... n_neighbors=2, weights=uniform, score=0.839, total=   0.8s
# [CV] n_neighbors=2, weights=uniform ..................................
# [CV] ...... n_neighbors=2, weights=uniform, score=0.831, total=   0.7s
# [CV] n_neighbors=2, weights=uniform ..................................
# [CV] ...... n_neighbors=2, weights=uniform, score=0.843, total=   0.7s
# [CV] n_neighbors=2, weights=distance .................................
# [CV] ..... n_neighbors=2, weights=distance, score=0.816, total=   0.6s
# [CV] n_neighbors=2, weights=distance .................................
# [CV] ..... n_neighbors=2, weights=distance, score=0.816, total=   0.6s
# [CV] n_neighbors=2, weights=distance .................................
# [CV] ..... n_neighbors=2, weights=distance, score=0.824, total=   0.6s
# [CV] n_neighbors=2, weights=distance .................................
# [CV] ..... n_neighbors=2, weights=distance, score=0.814, total=   0.6s
# [CV] n_neighbors=2, weights=distance .................................
# [CV] ..... n_neighbors=2, weights=distance, score=0.828, total=   0.6s
# [CV] n_neighbors=2, weights=distance .................................
# [CV] ..... n_neighbors=2, weights=distance, score=0.836, total=   0.6s
# [CV] n_neighbors=2, weights=distance .................................
# [CV] ..... n_neighbors=2, weights=distance, score=0.811, total=   0.6s
# [CV] n_neighbors=2, weights=distance .................................
# [CV] ..... n_neighbors=2, weights=distance, score=0.835, total=   0.6s
# [CV] n_neighbors=2, weights=distance .................................
# [CV] ..... n_neighbors=2, weights=distance, score=0.829, total=   0.5s
# [CV] n_neighbors=2, weights=distance .................................
# [CV] ..... n_neighbors=2, weights=distance, score=0.813, total=   0.6s
# [CV] n_neighbors=3, weights=uniform ..................................
# [CV] ...... n_neighbors=3, weights=uniform, score=0.861, total=   0.6s
# [CV] n_neighbors=3, weights=uniform ..................................
# [CV] ...... n_neighbors=3, weights=uniform, score=0.858, total=   0.7s
# [CV] n_neighbors=3, weights=uniform ..................................
# [CV] ...... n_neighbors=3, weights=uniform, score=0.851, total=   0.7s
# [CV] n_neighbors=3, weights=uniform ..................................
# [CV] ...... n_neighbors=3, weights=uniform, score=0.858, total=   0.7s
# [CV] n_neighbors=3, weights=uniform ..................................
# [CV] ...... n_neighbors=3, weights=uniform, score=0.860, total=   0.6s
# [CV] n_neighbors=3, weights=uniform ..................................
# [CV] ...... n_neighbors=3, weights=uniform, score=0.860, total=   0.6s
# [CV] n_neighbors=3, weights=uniform ..................................
# [CV] ...... n_neighbors=3, weights=uniform, score=0.850, total=   0.6s
# [CV] n_neighbors=3, weights=uniform ..................................
# [CV] ...... n_neighbors=3, weights=uniform, score=0.859, total=   0.7s
# [CV] n_neighbors=3, weights=uniform ..................................
# [CV] ...... n_neighbors=3, weights=uniform, score=0.869, total=   0.7s
# [CV] n_neighbors=3, weights=uniform ..................................
# [CV] ...... n_neighbors=3, weights=uniform, score=0.872, total=   0.7s
# [CV] n_neighbors=3, weights=distance .................................
# [CV] ..... n_neighbors=3, weights=distance, score=0.861, total=   0.7s
# [CV] n_neighbors=3, weights=distance .................................
# [CV] ..... n_neighbors=3, weights=distance, score=0.858, total=   0.6s
# [CV] n_neighbors=3, weights=distance .................................
# [CV] ..... n_neighbors=3, weights=distance, score=0.851, total=   0.6s
# [CV] n_neighbors=3, weights=distance .................................
# [CV] ..... n_neighbors=3, weights=distance, score=0.858, total=   0.6s
# [CV] n_neighbors=3, weights=distance .................................
# [CV] ..... n_neighbors=3, weights=distance, score=0.860, total=   0.6s
# [CV] n_neighbors=3, weights=distance .................................
# [CV] ..... n_neighbors=3, weights=distance, score=0.860, total=   0.5s
# [CV] n_neighbors=3, weights=distance .................................
# [CV] ..... n_neighbors=3, weights=distance, score=0.850, total=   0.6s
# [CV] n_neighbors=3, weights=distance .................................
# [CV] ..... n_neighbors=3, weights=distance, score=0.859, total=   0.6s
# [CV] n_neighbors=3, weights=distance .................................
# [CV] ..... n_neighbors=3, weights=distance, score=0.869, total=   0.6s
# [CV] n_neighbors=3, weights=distance .................................
# [CV] ..... n_neighbors=3, weights=distance, score=0.872, total=   0.7s
# [CV] n_neighbors=4, weights=uniform ..................................
# [CV] ...... n_neighbors=4, weights=uniform, score=0.861, total=   0.7s
# [CV] n_neighbors=4, weights=uniform ..................................
# [CV] ...... n_neighbors=4, weights=uniform, score=0.859, total=   0.7s
# [CV] n_neighbors=4, weights=uniform ..................................
# [CV] ...... n_neighbors=4, weights=uniform, score=0.848, total=   0.6s
# [CV] n_neighbors=4, weights=uniform ..................................
# [CV] ...... n_neighbors=4, weights=uniform, score=0.862, total=   0.7s
# [CV] n_neighbors=4, weights=uniform ..................................
# [CV] ...... n_neighbors=4, weights=uniform, score=0.852, total=   0.6s
# [CV] n_neighbors=4, weights=uniform ..................................
# [CV] ...... n_neighbors=4, weights=uniform, score=0.851, total=   0.6s
# [CV] n_neighbors=4, weights=uniform ..................................
# [CV] ...... n_neighbors=4, weights=uniform, score=0.843, total=   0.6s
# [CV] n_neighbors=4, weights=uniform ..................................
# [CV] ...... n_neighbors=4, weights=uniform, score=0.863, total=   0.6s
# [CV] n_neighbors=4, weights=uniform ..................................
# [CV] ...... n_neighbors=4, weights=uniform, score=0.864, total=   0.6s
# [CV] n_neighbors=4, weights=uniform ..................................
# [CV] ...... n_neighbors=4, weights=uniform, score=0.862, total=   0.6s
# [CV] n_neighbors=4, weights=distance .................................
# [CV] ..... n_neighbors=4, weights=distance, score=0.863, total=   0.6s
# [CV] n_neighbors=4, weights=distance .................................
# [CV] ..... n_neighbors=4, weights=distance, score=0.854, total=   0.6s
# [CV] n_neighbors=4, weights=distance .................................
# [CV] ..... n_neighbors=4, weights=distance, score=0.856, total=   0.6s
# [CV] n_neighbors=4, weights=distance .................................
# [CV] ..... n_neighbors=4, weights=distance, score=0.864, total=   0.6s
# [CV] n_neighbors=4, weights=distance .................................
# [CV] ..... n_neighbors=4, weights=distance, score=0.853, total=   0.6s
# [CV] n_neighbors=4, weights=distance .................................
# [CV] ..... n_neighbors=4, weights=distance, score=0.867, total=   0.6s
# [CV] n_neighbors=4, weights=distance .................................
# [CV] ..... n_neighbors=4, weights=distance, score=0.850, total=   0.7s
# [CV] n_neighbors=4, weights=distance .................................
# [CV] ..... n_neighbors=4, weights=distance, score=0.858, total=   0.6s
# [CV] n_neighbors=4, weights=distance .................................
# [CV] ..... n_neighbors=4, weights=distance, score=0.872, total=   0.6s
# [CV] n_neighbors=4, weights=distance .................................
# [CV] ..... n_neighbors=4, weights=distance, score=0.864, total=   0.6s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ...... n_neighbors=5, weights=uniform, score=0.865, total=   0.6s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ...... n_neighbors=5, weights=uniform, score=0.872, total=   0.6s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ...... n_neighbors=5, weights=uniform, score=0.866, total=   0.6s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ...... n_neighbors=5, weights=uniform, score=0.865, total=   0.6s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ...... n_neighbors=5, weights=uniform, score=0.860, total=   0.6s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ...... n_neighbors=5, weights=uniform, score=0.868, total=   0.6s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ...... n_neighbors=5, weights=uniform, score=0.853, total=   0.6s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ...... n_neighbors=5, weights=uniform, score=0.865, total=   0.6s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ...... n_neighbors=5, weights=uniform, score=0.874, total=   0.6s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ...... n_neighbors=5, weights=uniform, score=0.881, total=   0.7s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] ..... n_neighbors=5, weights=distance, score=0.865, total=   0.6s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] ..... n_neighbors=5, weights=distance, score=0.872, total=   0.6s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] ..... n_neighbors=5, weights=distance, score=0.866, total=   0.6s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] ..... n_neighbors=5, weights=distance, score=0.865, total=   0.6s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] ..... n_neighbors=5, weights=distance, score=0.860, total=   0.7s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] ..... n_neighbors=5, weights=distance, score=0.868, total=   0.7s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] ..... n_neighbors=5, weights=distance, score=0.853, total=   0.7s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] ..... n_neighbors=5, weights=distance, score=0.865, total=   0.7s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] ..... n_neighbors=5, weights=distance, score=0.874, total=   0.7s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] ..... n_neighbors=5, weights=distance, score=0.881, total=   0.7s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.884, total=   0.7s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.894, total=   0.7s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.874, total=   0.7s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.870, total=   0.8s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.873, total=   0.7s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.880, total=   0.7s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.873, total=   0.7s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.878, total=   0.6s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.890, total=   0.6s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.887, total=   0.6s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] .... n_neighbors=10, weights=distance, score=0.885, total=   0.6s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] .... n_neighbors=10, weights=distance, score=0.899, total=   0.6s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] .... n_neighbors=10, weights=distance, score=0.880, total=   0.6s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] .... n_neighbors=10, weights=distance, score=0.870, total=   0.6s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] .... n_neighbors=10, weights=distance, score=0.876, total=   0.7s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] .... n_neighbors=10, weights=distance, score=0.874, total=   0.6s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] .... n_neighbors=10, weights=distance, score=0.874, total=   0.6s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] .... n_neighbors=10, weights=distance, score=0.880, total=   0.6s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] .... n_neighbors=10, weights=distance, score=0.893, total=   0.6s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] .... n_neighbors=10, weights=distance, score=0.893, total=   0.6s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] ..... n_neighbors=15, weights=uniform, score=0.893, total=   0.7s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] ..... n_neighbors=15, weights=uniform, score=0.887, total=   0.6s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] ..... n_neighbors=15, weights=uniform, score=0.880, total=   0.7s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] ..... n_neighbors=15, weights=uniform, score=0.880, total=   0.7s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] ..... n_neighbors=15, weights=uniform, score=0.871, total=   0.7s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] ..... n_neighbors=15, weights=uniform, score=0.878, total=   0.6s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] ..... n_neighbors=15, weights=uniform, score=0.883, total=   0.7s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] ..... n_neighbors=15, weights=uniform, score=0.874, total=   0.6s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] ..... n_neighbors=15, weights=uniform, score=0.905, total=   0.6s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] ..... n_neighbors=15, weights=uniform, score=0.886, total=   0.6s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] .... n_neighbors=15, weights=distance, score=0.893, total=   0.7s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] .... n_neighbors=15, weights=distance, score=0.887, total=   0.6s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] .... n_neighbors=15, weights=distance, score=0.880, total=   0.6s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] .... n_neighbors=15, weights=distance, score=0.880, total=   0.6s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] .... n_neighbors=15, weights=distance, score=0.871, total=   0.6s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] .... n_neighbors=15, weights=distance, score=0.878, total=   0.6s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] .... n_neighbors=15, weights=distance, score=0.883, total=   0.6s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] .... n_neighbors=15, weights=distance, score=0.874, total=   0.6s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] .... n_neighbors=15, weights=distance, score=0.904, total=   0.7s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] .... n_neighbors=15, weights=distance, score=0.886, total=   0.6s
# [CV] n_neighbors=20, weights=uniform .................................
# [CV] ..... n_neighbors=20, weights=uniform, score=0.896, total=   0.6s
# [CV] n_neighbors=20, weights=uniform .................................
# [CV] ..... n_neighbors=20, weights=uniform, score=0.885, total=   0.6s
# [CV] n_neighbors=20, weights=uniform .................................
# [CV] ..... n_neighbors=20, weights=uniform, score=0.874, total=   0.6s
# [CV] n_neighbors=20, weights=uniform .................................
# [CV] ..... n_neighbors=20, weights=uniform, score=0.882, total=   0.7s
# [CV] n_neighbors=20, weights=uniform .................................
# [CV] ..... n_neighbors=20, weights=uniform, score=0.872, total=   0.7s
# [CV] n_neighbors=20, weights=uniform .................................
# [CV] ..... n_neighbors=20, weights=uniform, score=0.878, total=   0.7s
# [CV] n_neighbors=20, weights=uniform .................................
# [CV] ..... n_neighbors=20, weights=uniform, score=0.878, total=   0.7s
# [CV] n_neighbors=20, weights=uniform .................................
# [CV] ..... n_neighbors=20, weights=uniform, score=0.878, total=   0.7s
# [CV] n_neighbors=20, weights=uniform .................................
# [CV] ..... n_neighbors=20, weights=uniform, score=0.892, total=   0.7s
# [CV] n_neighbors=20, weights=uniform .................................
# [CV] ..... n_neighbors=20, weights=uniform, score=0.892, total=   0.7s
# [CV] n_neighbors=20, weights=distance ................................
# [CV] .... n_neighbors=20, weights=distance, score=0.895, total=   0.7s
# [CV] n_neighbors=20, weights=distance ................................
# [CV] .... n_neighbors=20, weights=distance, score=0.891, total=   0.7s
# [CV] n_neighbors=20, weights=distance ................................
# [CV] .... n_neighbors=20, weights=distance, score=0.872, total=   0.7s
# [CV] n_neighbors=20, weights=distance ................................
# [CV] .... n_neighbors=20, weights=distance, score=0.882, total=   0.7s
# [CV] n_neighbors=20, weights=distance ................................
# [CV] .... n_neighbors=20, weights=distance, score=0.875, total=   0.7s
# [CV] n_neighbors=20, weights=distance ................................
# [CV] .... n_neighbors=20, weights=distance, score=0.878, total=   0.7s
# [CV] n_neighbors=20, weights=distance ................................
# [CV] .... n_neighbors=20, weights=distance, score=0.875, total=   0.6s
# [CV] n_neighbors=20, weights=distance ................................
# [CV] .... n_neighbors=20, weights=distance, score=0.879, total=   0.7s
# [CV] n_neighbors=20, weights=distance ................................
# [CV] .... n_neighbors=20, weights=distance, score=0.894, total=   0.7s
# [CV] n_neighbors=20, weights=distance ................................
# [CV] .... n_neighbors=20, weights=distance, score=0.888, total=   0.7s
# {'n_neighbors': 15, 'weights': 'uniform'}
# 0.8836999999999999
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed:  1.7min finished

# %%
svc = KNeighborsClassifier(n_neighbors=15, weights='uniform')
svc.fit(x_train, y_train)

# Predict.
y_pred_svc = svc.predict(x_test)

# Getting the probabilities for each class.
y_prob_svc = svc.predict_proba(x_test)

y_test_bin_svc = label_binarize(y_test, classes=[0, 1, 2])

# %%
# Compute ROC curve and ROC area for each class.
fpr_gnb = dict()
tpr_gnb = dict()
fpr_log = dict()
tpr_log = dict()
fpr_svc = dict()
tpr_svc = dict()
roc_auc_gnb = dict()
roc_auc_log = dict()
roc_auc_svc = dict()
plt.figure(figsize=(14, 5))

lw = 2
for i in range(2):
    # Calculating ROC curve and ROC AUC.
    fpr_gnb[i], tpr_gnb[i], _ = roc_curve(y_test_bin_gnb[:, i], y_prob_gnb[:, i])
    roc_auc_gnb[i] = auc(fpr_gnb[i], tpr_gnb[i])
    
    fpr_log[i], tpr_log[i], _ = roc_curve(y_test_bin_log[:, i], y_prob_log[:, i])
    roc_auc_log[i] = auc(fpr_log[i], tpr_log[i])
    
    fpr_svc[i], tpr_svc[i], _ = roc_curve(y_test_bin_svc[:, i], y_prob_svc[:, i])
    roc_auc_svc[i] = auc(fpr_svc[i], tpr_svc[i])
    
    # Plotting ROC curve for class i.
    ax = plt.subplot(1, 2, i + 1)
    plt.plot(fpr_log[i], tpr_log[i], color='red', lw=lw, label='ROC curve (area = %0.2f) :: log' % roc_auc_log[i])
    plt.plot(fpr_gnb[i], tpr_gnb[i], color='blue', lw=lw, label='ROC curve (area = %0.2f) :: gnb' % roc_auc_gnb[i])
    plt.plot(fpr_svc[i], tpr_svc[i], color='green', lw=lw, label='ROC curve (area = %0.2f) :: knn' % roc_auc_svc[i])
    
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC - Class '+str(i))
    plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# # Resposta:

# %%
'''

Ao se observar as curvas ROC e também as áreas AUC, podemos afirmar que o classificador de Regressão Logistica 
teve melhor desempenho com relação às outras, devido ao fato de ter uma maior aproximação do eixo True Positive Ratio
sendo que o eixo False Positive fica o mais perto de zero possível, e também, consequentemente, ter uma maior AUC.


'''
